# %% [markdown]
# # Install librairies

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# # Load datasets

# %%
# exercices_data_path = "../datasets/gym_exercise_dataset.csv"
# df = pd.read_csv(exercices_data_path)
# df

programs_path = "../datasets/programs_detailed_boostcamp_kaggle.csv"
df = pd.read_csv(programs_path)
df

# stretch_data_path = "../datasets/stretch_exercise_dataset.csv"
# df2 = pd.read_csv(stretch_data_path)
# df2
# Out:
#                        Exercise Name             Equipment Variation  \
# 0                       Neck Flexion                 Cable        No
# 1                       Neck Flexion  Lever (plate loaded)        No
# 2               Lateral Neck Flexion  Lever (plate loaded)        No
# 3                       Neck Flexion  Lever (selectorized)        No
# 4               Lateral Neck Flexion  Lever (selectorized)        No
# ..                               ...                   ...       ...
# 612         Lying Reverse Calf Press                  Sled        No
# 613        Seated Reverse Calf Press                  Sled        No
# 614               Reverse Calf Raise                 Smith        No
# 615               Reverse Calf Raise           Body Weight        No
# 616  Reverse Calf Raise:  Single Leg           Body Weight       Yes
#
#                 Utility Mechanics Force  \
# 0    Basic or Auxiliary  Isolated  Pull
# 1    Basic or Auxiliary  Isolated  Pull
# ...

# %%
unique_exercices = df['Exercise Name'].nunique()

print(f"There are {unique_exercices} unique exercices in the dataset.")
# Out:
# There are 340 unique exercices in the dataset.

# %%
# Remove the rows with missing values in the 'Target muscle' feature
df = df.dropna(subset=['Target_Muscles'])
df
# Out:
#                          Exercise Name      Equipment Variation  \
# 7               Wall Front Neck Bridge    Body Weight        No
# 43                         Front Raise      Suspended        No
# 59                             Y Raise      Suspended        No
# 76   Rear Delt Inverted Row (high bar)    Body Weight        No
# 77    Rear Delt Inverted Row (on hips)    Body Weight        No
# ..                                 ...            ...       ...
# 556    Straight Hip Leg Curl (on ball)    Body Weight        No
# 557                   Inverse Leg Curl  Self-assisted        No
# 558                           Leg Curl      Suspended        No
# 559                   Hanging Leg Curl      Suspended        No
# 560              Straight Hip Leg Curl      Suspended        No
#
#                 Utility Mechanics        Force  \
# 7    Basic or Auxiliary  Isolated  Push & Pull
# 43            Auxiliary  Isolated         Push
# 59            Auxiliary  Isolated         Pull
# ...
