# %%
from ml_injury_risk_synthetic import train_and_save_model

injury_data_path = "../datasets/injury_data.csv"

train_and_save_model(injury_data_path)
# Out:
# Injury Risk Model – Evaluation
#               precision    recall  f1-score   support
#
#            0       0.53      0.50      0.51       100
#            1       0.52      0.55      0.54       100
#
#     accuracy                           0.53       200
#    macro avg       0.53      0.53      0.52       200
# weighted avg       0.53      0.53      0.52       200
#
# Model saved at models/injury_risk_synthetic.joblib
